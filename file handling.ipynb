# %%
print("hello")
# Out:
# hello

# %%
file=open("hello world.txt", "r")
for line in file:
   print(line)
# Out:
# hello world
#
# my name is anil kumar yadav
#
# this is text file

# %%
file=open("hello world.txt", "r")
print(file.read())
# Out:
# hello world
# my name is anil kumar yadav
# this is text file

# %%
print(file.read(5))
